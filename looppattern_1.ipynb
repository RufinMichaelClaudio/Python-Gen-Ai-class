# %%
n = 5
newstr = ''

for i in range(n):
    stars = '*' * (2 * (n - i) - 1)
    spaces = ' ' * i
    newstr = spaces + stars
    print(newstr)
# Out:
# *********
#  *******
#   *****
#    ***
#     *
