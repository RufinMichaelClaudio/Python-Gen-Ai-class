# %%
num = int(input("enter a number"))
sym = input("enter a symbol")

for x in range (num):
    for y in range(0,num,1):
        print(sym, end=' ')
    print()
# Out:
# # # # # # # # #
# # # # # # # # #
# # # # # # # # #
# # # # # # # # #
# # # # # # # # #
# # # # # # # # #
# # # # # # # # #
# # # # # # # # #
