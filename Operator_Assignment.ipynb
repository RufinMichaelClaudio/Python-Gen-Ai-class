# %%
X = 10
Y = 5
print(X + Y)
print(X * Y)
# Out:
# 15
# 50

# %%
name = "Python"
print("Hello", name)
# Out:
# Hello Python

# %%
a = "10"
b = int(a)
print(b + 5)
# Out:
# 15

# %%
numbers = [10, 20, 30]
print(numbers[1])
# Out:
# 20

# %%
student = {"name": "Arun", "age": 20}
print(student["name"])
# Out:
# Arun
