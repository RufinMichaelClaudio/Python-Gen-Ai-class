# %%
num = int(input("enter a number: "))
symbol = input("enter a symbol: ")

for x in range (num):
    for y in range (x-1):
        print(symbol,end='')
    print()
# Out:
# $
# $$
# $$$

# %%
num = int(input("enter a number: "))
symbol = input("enter a symbol: ")

for x in range (num, 0, -1):
    for y in range (x):
        print(symbol,end='')
    print()
# Out:
# #####
# ####
# ###
# ##
# #
