# %%
row = int(input("enter number of rows: "))
column = int(input("enter number of columns: "))
a = 1
while a <= row:
    b = 1
    while b <= column:
        print(b, end = "")
        b += 1
    a += 1
    print()
# Out:
# 123
# 123

# %% [markdown]
# python for loop
#
# Range ()
